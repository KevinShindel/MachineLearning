# %% [markdown]
# In this notebook, we'll train an RNN to predict the next character given a sequence of characters coming from a text. Such models are also frequently referred to as "language models".
#
# We'll use the book "Pride and Prejudice" from Project Gutenberg here to train our model:

# %%
# !wget https://www.gutenberg.org/files/1342/1342-0.txt -O prideandprejudice.txt
# Out:
# --2020-07-21 13:35:41--  https://www.gutenberg.org/files/1342/1342-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 799738 (781K) [text/plain]
# Saving to: ‘prideandprejudice.txt’
#
# prideandprejudice.t 100%[===================>] 780.99K   471KB/s    in 1.7s
#
# 2020-07-21 13:35:43 (471 KB/s) - ‘prideandprejudice.txt’ saved [799738/799738]

# %%
# %tensorflow_version 2.x

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Embedding, LSTM, Attention, Input, Flatten
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.datasets import imdb
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing import sequence
import numpy as np
import random
import re
import io

# %% [markdown]
# Next, we read in the file and do some basic processing:

# %%
text = io.open('prideandprejudice.txt', encoding='utf-8').read().lower().replace('\n', ' ').replace('\ufeff', '')
text = re.compile(r"\s+").sub(" ", text).strip()

chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

print('Corpus length   =', len(text))
print('Total chars     =', len(chars))
print('First ten chars =', chars[:10])
# Out:
# Corpus length   = 701860
# Total chars     = 64
# First ten chars = [' ', '!', '#', '$', '%', "'", '(', ')', '*', ',']

# %% [markdown]
# Next, we will cut the text up into semi-redundant sequences of `maxlen` characters:

# %%
maxlen = 80
step   = 3

sentences  = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Nr. of sequences =', len(sentences))
# Out:
# Nr. of sequences = 233927

# %% [markdown]
# Let's take a look at a couple of examples of train X/y instances we have now:

# %%
for i in range(10):
  print(sentences[i], '-->', next_chars[i])
# Out:
# the project gutenberg ebook of pride and prejudice, by jane austen this ebook is -->
#  project gutenberg ebook of pride and prejudice, by jane austen this ebook is fo --> r
# oject gutenberg ebook of pride and prejudice, by jane austen this ebook is for t --> h
# ct gutenberg ebook of pride and prejudice, by jane austen this ebook is for the  --> u
# gutenberg ebook of pride and prejudice, by jane austen this ebook is for the use -->
# enberg ebook of pride and prejudice, by jane austen this ebook is for the use of -->
# erg ebook of pride and prejudice, by jane austen this ebook is for the use of an --> y
#  ebook of pride and prejudice, by jane austen this ebook is for the use of anyon --> e
# ook of pride and prejudice, by jane austen this ebook is for the use of anyone a --> n
#  of pride and prejudice, by jane austen this ebook is for the use of anyone anyw --> h

# %% [markdown]
# We still need to convert these valid inputs, so let's do that now. Here, we're using a one-hot encoding mechanism given the low number of characters, but an embedding would work as well, in which case we could convert each sentence to a sequence of integers.

# %%
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)),         dtype=np.bool)

for i, sentence in enumerate(sentences):
  for t, char in enumerate(sentence):
      X[i, t, char_indices[char]] = 1
  y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# We can now define our network:

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               98816
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# =================================================================
# Total params: 107,072
# Trainable params: 107,072
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We're going to do something clever here. We'll use a Keras callback here to see how well our model is doing every so often.
#
# However, just taking the predicted next character from the network would be pretty boring, as it is very likely our network will get stuck in loops. A better technique is hence weighted sampling from the predictions using some "temperature" parameter. The lower the temperature, the more we'll stick to the most-sure prediction:

# %%
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds  = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %% [markdown]
# We then define our callback function:

# %%
def on_epoch_end(epoch, logs):
  print()
  if epoch % 5 != 0: return

  print('Generating text after epoch {}'.format(epoch))

  # Start from a random piece of text:
  start_index = random.randint(0, len(text) - maxlen - 1)
  
  for temperature in [0.2, 1.0]:
      sentence = text[start_index: start_index + maxlen]
      
      print('(temperature = {})'.format(temperature), sentence, end='  -->  ')

      # Predict 400 characters
      for i in range(400):

          # Prepare input based on sentence so far
          X_pred = np.zeros((1, maxlen, len(chars)))
          for t, char in enumerate(sentence):
              X_pred[0, t, char_indices[char]] = 1.

          # Predict and sample
          preds      = model.predict(X_pred, verbose=0)[0]
          next_index = sample(preds, temperature)
          next_char  = indices_char[next_index]

          # Change the sentence so far (shifting the window to the right)
          sentence = sentence[1:] + next_char

          print(next_char, end='')

      print()

# %% [markdown]
# And let's train: note the difference in behavior given the temperature we specify:

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
model.fit(X, y, batch_size=256, epochs=60, verbose=0, callbacks=[print_callback])
# Out:
# Generating text after epoch 0
# (temperature = 0.2) ied only with a laugh; and as it had been asked without the least suspicion, she  -->   the the the the mared and and he the mist and an the here the the the coulling wat and and and the the the sound was ther and and the the ther the he the ther soung the her the her ind and and and and and the hat and and and and and in the hith and and ind the ther the the the sout and and the the the the lese the her ant and soull the the the the ther and and and and and and and and and and the
# (temperature = 1.0) ied only with a laugh; and as it had been asked without the least suspicion, she  -->   whas te mocitbesther bo estul, bve tichedurse ilsurtti kfithe lis hem, whe, onljiginot orethein , andan ithe, wasy is horr the ah orseveghos ithe nobewysun avet ahe, oblwidest. yom. frrelkavr ur axeg, qu rrenquiny bytit oud cthenl”d. —i vem e sougt, anwashe he cerithonth wh alcenerell tatheed them st culgcltady bed thowik cass benove s, axdef oi woreathyof anethe coprelidid ce too cy hed aangad i
#
#
#
#
#
# Generating text after epoch 5
# (temperature = 0.2) ave passed within ten miles of us. colonel forster gives us reason to expect him  -->   so mary a free so mary her sar more the was so mont of her some to she wish her so me to mr. darcy and the could he was so and her so me that whe had be not her so me to man the parter as she wish her sure the some be of the was so the was so the was so the was not she had the was so not an the parting the was so the could the partion to me the was so the was so the was so the was so the was so t
# (temperature = 1.0) ave passed within ten miles of us. colonel forster gives us reason to expect him  -->   seenrgation to am—chit ofthind she alidiced fil much pos to mron adcrestat merked altod of ertakequations; and thid aginet, scome sonigh ceme. thow slo had plost of nem. chichins, it not in thomben, dely prong un vi has stel dost that oniong of the was fol-ther peacly.” shat wus sy, a dad compruline wes mr. darcay, a me a avery wis grooth whan ind. “the spectitibute ithit well do him her pemest y
#
#
#
#
#
# Generating text after epoch 10
# (temperature = 0.2) ibuting any project gutenberg-tm works unless you comply with paragraph 1.e.8 or  -->   the prother with a look the had not the sar and her for the had not the for the selling the such an the concerned the was the was not the project of the parting and her from the had not the was a most and she was not the had not the was not the project of the for the surse a mont of her sister of the project of the consinted of the parting her the sarter and she could not the had not in a morn th
# (temperature = 1.0) ibuting any project gutenberg-tm works unless you comply with paragraph 1.e.8 or  -->   your tuther overeand’s manes could st. the been her tow of _nilit even the maghtore, to with my was not infer, by have plead mr. unen haws impersent not doscos; and leawing and a most of drarge, and poomel was the plaixile atredinger. them. lady have for miss interation. you had drizately which as ferfans withous to om arcistable, mrsem amm; and cains, as shather’s fann rothering it. it is vitter
#
#
#
#
#
# Generating text after epoch 15
# (temperature = 0.2) ennet had slept ill, and though up, was very feverish, and not well enough to le  -->  ast was so elizabeth was not be so such an a more the present of the sure in the sure you are she was a promess of the sure to she was a warked and the repersed to her such a particular with the lady carriage the present of the could not be a senged the could not be any one of the present of the former and a more the sure i have been and a seling the sure you are such a senged to the will as the l
# (temperature = 1.0) ennet had slept ill, and though up, was very feverish, and not well enough to le  -->  frerine’s dose me of turno, by oblight her vise. but was should him. mr. darcy said age. but to be sale, if you, you; that youll not im_ fild had but you gassed?” “nizzy with any with the grefuctle to relice, with seeling maked, to usents the forth of the partituratily her, and jane,” so will now some ady of much eigh _yow migh mirshing but my her weling in the trile on one speritatess but hald th
#
#
#
#
#
# Generating text after epoch 20
# (temperature = 0.2) uch a user to return or destroy all copies of the works possessed in a physical   -->  to be all the former and all the first have been and a sure to her for the present of the present of her former to her friend the present of the sure the present of the forth the lady catherine to her freether was considered to her father was all the present of the sure the miss did not the first and all the most and the evening to her friend the stread the present of her friend to be the first ha
# (temperature = 1.0) uch a user to return or destroy all copies of the works possessed in a physical   -->  told of ansu for than have to the ever the oke, all the twoing-himston of her from her. with my conscivil ablowed up missiding them to ter risclonacte.” “if that as least and her brengef mr. collins’s allfices, but would not _she_ _the_ somes.
#
#
#
#
# Generating text after epoch 25
# (temperature = 0.2)  darcy, she moved again towards the gate. he had by that time reached it also, a  -->  nd her unseres to see miss darcy was such a send an the was so far so much a send an ever sister, who had been all the compasion of her sister so propanting to her to the wished again and her complay of her sister of her sister the consider to her sister the will be a sended to be in the consected to her sister, and the sather was so for so to the some to the resent of seem to her for her for her
# (temperature = 1.0)  darcy, she moved again towards the gate. he had by that time reached it also, a  -->  ffected by have two darcy succerse. “mind, peilding one. they vautes to this. her family, i was now deal is more were this side, and such af her such mrs. hers. she could on contently and all pridats in mirit. that as the morring surple of heard unduan face i have been comsciming the ne lefting as the paltunity to sid ever a one i ought in pemberly,” had been follous and as she was one he me to se
#
#
#
#
#
# Generating text after epoch 30
# (temperature = 0.2) t it is,” returned she; “for mrs. long has just been here, and she told me all a  -->  t a most an attention of the party to be an appraiched that he was not all the family with some to the project gutenberg-tm told her any sister of the particular of the last the sater and considered to her father will be to be to be all the party, and the project gutenberg-tm told her sisters the concern in the particular of the particular to see the particular again and the say to be the party as
# (temperature = 1.0) t it is,” returned she; “for mrs. long has just been here, and she told me all a  -->  ny all-tle me strentwery that loved awas town hersfight that that, _ous_, i stared by his came. shopt it wall of pooling-fulliessed to anver my deariss mrs. bennet bear of thank them was in the discriss the quite intitions it to his known?” “you mrs. bennet cannot, was with interately not thank of thy word been liggley, and mr. collins’s dear with the other, mr. parchus. no seeftion. it nothing, “
#
#
#
#
#
# Generating text after epoch 35
# (temperature = 0.2)  my giving you the wished-for promise make _their_ marriage at all more probable  -->   of his compliments to mr. darcy was the project gutenberg-tm toon the little and any at the particular again and a moment of the project gutenberg-tm elizabeth was not any of the liberation with the little and any attention to be so into all the particularly to the project gutenberg-tm elizabeth, and and her daughters and she could not be books and sister with the strong in the first compliment o
