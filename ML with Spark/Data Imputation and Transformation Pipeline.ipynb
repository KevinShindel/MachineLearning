# %%
from pyspark.sql import SparkSession
from service import create_spark

# %%
spark: SparkSession = create_spark()

# %%
# TODO: Donwload data from Kaggle
# https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("blastchar/telco-customer-churn")

print("Path to dataset files:", path)

# %%
# TODO: See implementation at https://github.com/abbassalsharif/data-preparation-for-machine-learning-with-databricks/tree/main
