# %%
from sklearn.naive_bayes import GaussianNB
from SciKit.utils import split_500_hits, show_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# | Model                      | DataSet | Time  | F1 Score | Scaling | Cross Score | ROC AUC |
# |----------------------------|---------|-------|----------|---------|-------------|---------|
# | GaussianNB                 | 500     | 261ms | 0.83     | No      | ?           | ?       |
# | LogisticRegression         | 500     | 298ms | 0.83     | No      | ?           | ?       |
# | RandomForestClassifier     | 500     | 398ms | 0.91     | No      | ?           | ?       |
# | SVC                        | 500     | 198ms | 0.90     | Yes     | ?           | ?       |
# | DecisionTreeClassifier     | 500     | 185ms | 0.81     | No      | ?           | ?       |
# | KNeighborsClassifier       | 500     | 156ms | 0.86     | Yes ?   | ?           | ?       |
# | ExtraTreesClassifier       | 500     | 314ms | 0.88     | No      | ?           | ?       |
# | GradientBoostingClassifier | 500     | 91ms  | 0.89     | No      | ?           | ?       |

# %%
# TODO: add check for overfitting, underfitting, cross validation score, ROC AUC score

# %%
# load data
X_train, X_test, y_train, y_test = split_500_hits()

# %%
# create model
model = GaussianNB()
# fit model
model.fit(X_train, y_train)
# evaluate model
y_predict = model.predict(X_test)
show_report(y_test, y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88        66
#            1       0.68      0.78      0.72        27
#
#     accuracy                           0.83        93
#    macro avg       0.79      0.81      0.80        93
# weighted avg       0.84      0.83      0.83        93
#
# Accuracy:  0.8279569892473119
# Confusion Matrix:
#  [[56 10]
#  [ 6 21]]

# %%
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
show_report(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        66
#            1       0.77      0.89      0.83        27
#
#     accuracy                           0.89        93
#    macro avg       0.86      0.89      0.87        93
# weighted avg       0.90      0.89      0.89        93
#
# Accuracy:  0.8924731182795699
# Confusion Matrix:
#  [[59  7]
#  [ 3 24]]
