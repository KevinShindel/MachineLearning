# %% [markdown]
# ## Task 9: Train model coder-decoder which can transform string like 'April 22, 2019' into '2019-04-22'

# %% [markdown]
# ## Task 10: Read blueprint 'Neural machine translation with attention' → https://homl.info/nmtuto

# %% [markdown]
# ## Task 11: Using BERT to generate Shakespeare texts.
