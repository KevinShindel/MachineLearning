# %% [markdown]
# ## Task 9. Train Simple model and deploy it to Google AI Platform using TF Serving
# > - Write client code ( REST / gRPC ) to send prediction request to the model deployed on Google AI Platform and get the response back.
# > - Create version 2 and deploy it to Google AI Platform using TF Serving. Compare the performance of both versions and write your observations.
# > - Rollback to version 1 and write your observations.

# %% [markdown]
# ## Task 10: Train model using a few GPU's:
# > - using MirrorStrategy
# > - using MultiWorkerMirroredStrategy
# > - using CentralStorageStrategy

# %% [markdown]
# ## Task 11: Train small mode on AI Platform Google CLound using black-box training and hyperparameter tuning.
