# %% [markdown]
# ## Task 9: Use autoencoders train image classifier ( MNIST / CIFAR10 )
# - Split dataset into train / validation
# - Check if image fully restruckted
# - Train DNN for classification using lowest layers autoencoders.
# - - Train them using only 500 images
# - - Does the model working well with learning or without ?

# %% [markdown]
# ## Task 10: Train variative encoders on image dataset ( MNIST / CIFAR10/ other )
# - Use it for image generation
# - Use hidden piece of dataset and evaluate on it

# %% [markdown]
# ## Task 11: Train DCGAN net for work with selected dataset

# %%
# Example of code can be found in repo: https://github.com/ageron/handson-ml2/blob/master/17_autoencoders_and_gans.ipynb
